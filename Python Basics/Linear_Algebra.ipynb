# %% [markdown]
# What is a Vector? (ML Explanation)
#
# A vector is just a list of numbers.
#
# Example:
#
# [2, 5] → point on a 2D plane
#
# [3, 1, -2] → 3D point
#
# In ML, a vector = features of a data sample
#
# Example:
# A house = [ area, bedrooms, age ]
# → [1200, 3, 10] is a feature vector
#
# What is a Matrix?
#
# A matrix = collection of vectors arranged in rows/columns.
#
# ML datasets are basically matrices.
#
# Example dataset:
#
# Area	Bedrooms	Age
# 1200	3	        10
# 1500	4	         7
# 900	  2        	15
#
# This becomes:

# %%
[
  [1200, 3, 10],
  [1500, 4, 7],
  [900, 2, 15]
]

# %% [markdown]
# Basic Matrix Operations (with NumPy code)
# ➤ Vector Addition

# %%
import numpy as np

a = np.array([2, 4])
b = np.array([1, 3])

print(a + b)
# Out:
# [3 7]

# %% [markdown]
# Scalar Multiplication

# %%
v = np.array([2, 4, 6])
print(3 * v)
# Out:
# [ 6 12 18]

# %% [markdown]
# ➤ Dot Product (VERY IMPORTANT in ML)
#
# Used in:
#
# linear regression
#
# neural networks
#
# similarity measurement
#
# embeddings
#
# 👉 Formula:
# a · b = a1*b1 + a2*b2 + ...

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

print("Dot Product =", np.dot(a, b))
# Out:
# Dot Product = 32

# %% [markdown]
# ➤ Matrix Multiplication
#
# Used heavily in:
#
# Neural networks
#
# PCA
#
# Computer vision

# %%
A = np.array([[1, 2],
              [3, 4]])

B = np.array([[5, 6],
              [7, 8]])

print(A @ B)
# Out:
# [[19 22]
#  [43 50]]

# %% [markdown]
# Why ML Needs Linear Algebra?
# ML Concept	Uses Linear Algebra
# Linear Regression	dot products & matrix inverse
# Neural Networks	matrix multiplication
# PCA	eigenvalues & eigenvectors
# Clustering	vector distances
# Deep Learning	tensors
#
# If you understand vectors + matrices, ML becomes easy.
